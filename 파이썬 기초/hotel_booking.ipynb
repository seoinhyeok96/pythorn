# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as pt
from math import sqrt
from scipy.stats import chi2_contingency

# %%
df =pd.read_csv('chap4-hotel_booking_case_study.csv')
df.head()
# Out:
#    NRDeposit  IsCanceled DistributionChannel MarketSegment CustomerType  \
# 0          0           0              Direct        Direct    Transient
# 1          0           0              Direct        Direct    Transient
# 2          0           0              Direct        Direct    Transient
# 3          0           0           Corporate     Corporate    Transient
# 4          0           0               TA/TO     Online TA    Transient
#
#    Children   ADR  PreviousCancellations  IsRepeatedGuest Country Quarter  \
# 0         0   0.0                      0                0     PRT      Q3
# 1         0   0.0                      0                0     PRT      Q3
# 2         0  75.0                      0                0     GBR      Q3
# 3         0  75.0                      0                0     GBR      Q3
# 4         0  98.0                      0                0     GBR      Q3
#
#    Year
# 0  2015
# 1  2015
# 2  2015
# 3  2015
# 4  2015

# %% [markdown]
# # 보증금 유형이 예약 취소율에 영향을 주는가?

# %%
table_cnt  = df.groupby(['NRDeposit','IsCanceled']).\
agg(cnt = ('Country', lambda x : len(x)))
table_cnt
# Out:
#                         cnt
# NRDeposit IsCanceled
# 0         0           63316
#           1           23042
# 1         0              55
#           1             982
